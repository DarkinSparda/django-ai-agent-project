# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: admin>, <User: staff>]>

# %%
User.objects.create(username='abdullah',is_staff=True).save()

# %%
help(User)

# %%
User.objects.filter(is_superuser=True).first().user_permissions.all()
# Out:
# <QuerySet []>

# %%
weak_user_obj = User.objects.last()
weak_user_obj.user_permissions.all()
# Out:
# <QuerySet []>

# %%
staff_u = User.objects.filter(is_superuser=False, is_staff=True).first()

# %%
from django.contrib.auth.models import Permission

perms_qs = Permission.objects.filter(codename__icontains='view')
for x in perms_qs:
    print(x.codename)

staff_u.user_permissions.set(perms_qs)
# Out:
# view_logentry
# view_group
# view_permission
# view_user
# view_contenttype
# view_document
# view_session

# %%
staff_u.is_staff=True
staff_u.save()

# %%
staff_u.set_password('123q')
staff_u.save()

# %%
staff_u
# Out:
# <User: abdullah>

# %%
perms_doc = Permission.objects.filter(codename__iendswith='DoCuMenT')
# for x in perms_doc:
#     print(x.codename)
# print('xxcxxcxxcxxcxxcxxc'.upper())
perms_view = Permission.objects.filter(codename__icontains='viEW')
# for x in perms_view:
#     print(x.codename)

view_and_docs_perms = perms_view | perms_doc


# perm set

abdullah = User.objects.get(id=3)
print(abdullah.user_permissions.all())

abdullah.user_permissions.set(view_and_docs_perms)
abdullah.user_permissions.all()
# Out:
# <QuerySet [<Permission: Administration | log entry | Can view log entry>, <Permission: Authentication and Authorization | group | Can view group>, <Permission: Authentication and Authorization | permission | Can view permission>, <Permission: Authentication and Authorization | user | Can view user>, <Permission: Content Types | content type | Can view content type>, <Permission: Documents | document | Can add document>, <Permission: Documents | document | Can change document>, <Permission: Documents | document | Can delete document>, <Permission: Documents | document | Can view document>, <Permission: Sessions | session | Can view session>]>
# ...

# %%
id4 = User.objects.get(id=4)
Document.objects.last()
# Out:
# <Document: <Document: id4's private DOC>>
