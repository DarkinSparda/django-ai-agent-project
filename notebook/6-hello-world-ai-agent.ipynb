# %%
import setup
setup.init()

# %%
from ai.agents import get_document_agent

# %%
agent = get_document_agent()

# %%
import uuid

config = {"configurable": {
    "user_id": "1",
    "thread_id": uuid.uuid4(),
    }
}

# %%
agent.invoke(
    {"messages": [{
        "role": 'user',
        "content": "What is the most recent documents I have?"
    }
    ]},
    config
)
# Out:
# Config:  {'tags': [], 'metadata': {'user_id': '1', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:30728b3e-e51c-d6a6-6780-3834cc504507', 'checkpoint_ns': 'tools:30728b3e-e51c-d6a6-6780-3834cc504507'}, 'callbacks': <langchain_core.callbacks.manager.CallbackManager object at 0x748d902994c0>, 'recursion_limit': 25, 'configurable': {'user_id': '1', 'thread_id': UUID('45e39990-d01b-465d-a725-088521f9f951'), '__pregel_runtime': Runtime(context=None, store=None, stream_writer=<function Pregel.stream.<locals>.stream_writer at 0x748d92bf1800>, previous=None), '__pregel_task_id': '30728b3e-e51c-d6a6-6780-3834cc504507', '__pregel_send': <built-in method extend of collections.deque object at 0x748db4600220>, '__pregel_read': functools.partial(<function local_read at 0x748d9d63fba0>, PregelScratchpad(step=2, stop=25, call_counter=<langgraph.pregel._algo.LazyAtomicCounter obj
# ...
