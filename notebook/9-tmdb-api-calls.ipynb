# %%
import setup
setup.init()

from aiproject.prettifier import pprint
from ai.agents import get_document_agent
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %%
agent = get_document_agent()

# %%
from tmdb import client as tmdb_client

# %%
tmdb_client.get_headers()
# Out:
# {'accept': 'application/json',
#  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1MTdlODA5NjFiYzBiM2QxNDIzNDcwNTYyOWRlMjhlMyIsIm5iZiI6MTc2MjQzMjMxMS41ODIsInN1YiI6IjY5MGM5NTM3MTFjZTcyOTg2NjA3MTYxZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.KW6z9BVy_1KJwmnHVBKXejrcy8ImntuUTeo-aK1sUco'}

# %%
tmdb_client.movie_details(872585)
# Out:
# {'adult': False,
#  'backdrop_path': '/neeNHeXjMF5fXoCJRsOmkNGC7q.jpg',
#  'belongs_to_collection': None,
#  'budget': 100000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#  'homepage': 'https://www.universalpictures.com/movies/oppenheimer',
#  'id': 872585,
#  'imdb_id': 'tt15398776',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Oppenheimer',
#  'overview': "The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.",
#  'popularity': 18.3298,
#  'poster_path': '/8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg',
#  'production_companies': [{'id': 9996,
#    'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png',
#    'name': 'Syncopy',
#    'origin_country': 'GB'},
#   {'id': 33,
#    'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#    'name': 'Universal Pictures',
#    'origin_country': 'US'},
#   {'id': 507,
#    'logo_path': '/aRmHe6GWxYMRCQljF75rn2B9Gv8.png',
#    'name': 'Atlas Entertainment',
#    'origin_country': 'US'},
#   {'id': 15123,
#    'logo_path': None,
#    'name': 'Breakheart Films',
#    'origin_country': 'US'},
#   {'id': 239215,
#    'logo_path': None,
#    'name': 'Peters Creek Entertainment',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2023-07-19',
#  'revenue': 952000000,
#  'runtime': 181,
#  'spoken_languages': [{'english_name': 'Dutch',
#    'iso_639_1': 'nl',
#    'name': 'Nederlands'},
#   {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'The world forever changes.',
#  'title': 'Oppenheimer',
#  'video': False,
#  'vote_average': 8.046,
#  'vote_count': 10902}

# %%
import uuid

config = {"configurable": {
    "user_id": '2',
    "thread_id": uuid.uuid4(),
    }
}

# %%
res = agent.invoke(
    {"messages": [{
        "role": 'user',
        "content": "i wanted direct_doc1 give me its content",
    }
    ]},
    config,
)
res
pprint(res['messages'][-1].content)
# Out:
# Config:  {'tags': [], 'metadata': {'user_id': '2', 'langgraph_step': 45, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:b3bcd719-5833-4e41-0d49-c4aac759dfac', 'checkpoint_ns': 'tools:b3bcd719-5833-4e41-0d49-c4aac759dfac'}, 'callbacks': <langchain_core.callbacks.manager.CallbackManager object at 0x791af17ce030>, 'recursion_limit': 25, 'configurable': {'user_id': '2', 'thread_id': UUID('c0b45a57-f0ae-46d9-91ac-b4808a8c94f1'), '__pregel_runtime': Runtime(context=None, store=None, stream_writer=<function Pregel.stream.<locals>.stream_writer at 0x791af162ea20>, previous=None), '__pregel_task_id': 'b3bcd719-5833-4e41-0d49-c4aac759dfac', '__pregel_send': <built-in method extend of collections.deque object at 0x791af16326b0>, '__pregel_read': functools.partial(<function local_read at 0x791b3615be20>, PregelScratchpad(step=45, stop=68, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd9c0>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd000>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x791af1682340>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd4e0>), {'messages': <langgraph.channels.binop.BinaryOperatorAggregate object at 0x791af1622b40>, 'jump_to': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x791af16238c0>, 'structured_response': <langgraph.channels.last_value.LastValue object at 0x791af1622840>, '__start__': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x791af1623580>, '__pregel_tasks': <langgraph.channels.topic.Topic object at 0x791af16239c0>, 'branch:to:model': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x791af1620480>, 'branch:to:tools': <langgraph.channels.ephemeral_value.EphemeralValue object at 0x791af1623880>}, {}, PregelTaskWrites(path=('__pregel_push', 0, False), name='tools', writes=deque([]), triggers=('__pregel_push',))), '__pregel_checkpointer': <langgraph.checkpoint.memory.InMemorySaver object at 0x791b340f25a0>, 'checkpoint_map': {'': '1f0bb0a9-4f04-6762-802c-063dce7cb56d'}, 'checkpoint_id': None, 'checkpoint_ns': 'tools:b3bcd719-5833-4e41-0d49-c4aac759dfac', '__pregel_scratchpad': PregelScratchpad(step=45, stop=68, call_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd9c0>, interrupt_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd000>, get_null_resume=<function _scratchpad.<locals>.get_null_resume at 0x791af1682340>, resume=[], subgraph_counter=<langgraph.pregel._algo.LazyAtomicCounter object at 0x791af17cd4e0>), '__pregel_call': functools.partial(<function _call at 0x791b3618d9e0>, <weakref at 0x791af0aa8a40; to 'PregelExecutableTask' at 0x791af167f1d0>, retry_policy=None, futures=<weakref at 0x791af0aa9850; to 'FuturesDict' at 0x791af0aa9b30>, schedule_task=<bound method SyncPregelLoop.accept_push of <langgraph.pregel._loop.SyncPregelLoop object at 0x791af17cfd40>>, submit=<weakref at 0x791af0a055d0; to 'BackgroundExecutor' at 0x791af17ce480>)}}
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>"The document \"direct_doc1\" has no content."</pre>

# %%
pprint(res['messages'][-1].content)
# Out:
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>"I found one document titled \"direct_doc1\". I also found \"direct_doc\" and \"Hello world\". \"direct_doc\" seems like a possible alternative with an extra underscore. Would you like to examine its content?"</pre>
