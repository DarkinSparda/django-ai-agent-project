# %%
import setup
setup.init()

from aiproject.prettifier import pprint
from ai.agents import get_document_agent, get_movies_agent
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %%
doc_agent = get_document_agent()
mov_agent = get_movies_agent()

# %%
from tmdb import client as tmdb_client

# %%
tmdb_client.get_headers()
# Out:
# {'accept': 'application/json',
#  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1MTdlODA5NjFiYzBiM2QxNDIzNDcwNTYyOWRlMjhlMyIsIm5iZiI6MTc2MjQzMjMxMS41ODIsInN1YiI6IjY5MGM5NTM3MTFjZTcyOTg2NjA3MTYxZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.KW6z9BVy_1KJwmnHVBKXejrcy8ImntuUTeo-aK1sUco'}

# %%
tmdb_client.movie_details(872585)
# Out:
# {'adult': False,
#  'backdrop_path': '/neeNHeXjMF5fXoCJRsOmkNGC7q.jpg',
#  'belongs_to_collection': None,
#  'budget': 100000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#  'homepage': 'https://www.universalpictures.com/movies/oppenheimer',
#  'id': 872585,
#  'imdb_id': 'tt15398776',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Oppenheimer',
#  'overview': "The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.",
#  'popularity': 18.3298,
#  'poster_path': '/8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg',
#  'production_companies': [{'id': 9996,
#    'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png',
#    'name': 'Syncopy',
#    'origin_country': 'GB'},
#   {'id': 33,
#    'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#    'name': 'Universal Pictures',
#    'origin_country': 'US'},
#   {'id': 507,
#    'logo_path': '/aRmHe6GWxYMRCQljF75rn2B9Gv8.png',
#    'name': 'Atlas Entertainment',
#    'origin_country': 'US'},
#   {'id': 15123,
#    'logo_path': None,
#    'name': 'Breakheart Films',
#    'origin_country': 'US'},
#   {'id': 239215,
#    'logo_path': None,
#    'name': 'Peters Creek Entertainment',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2023-07-19',
#  'revenue': 952000000,
#  'runtime': 181,
#  'spoken_languages': [{'english_name': 'Dutch',
#    'iso_639_1': 'nl',
#    'name': 'Nederlands'},
#   {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'The world forever changes.',
#  'title': 'Oppenheimer',
#  'video': False,
#  'vote_average': 8.046,
#  'vote_count': 10903}

# %%
import uuid

config = {"configurable": {
    "user_id": '2',
    "thread_id": uuid.uuid4(),
    }
}

# %%
res = mov_agent.invoke(
    {"messages": [{
        "role": 'user',
        "content": "Search for the last movie i told you to search.",
    }
    ]},
    config,
)
res
pprint(res['messages'][-1].content)
# Out:
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>"I’m missing the prior search context — I don’t have a record of the “last movie” you previously asked about. Tell me the movie title or give keywords/criteria (genre, actor, year, plot points) and I’ll run the search.\n\nExamples you can reply with:\n- A title: “Search for The Matrix”\n- A year + genre: “sci‑fi movies from 2010–2020”\n- An actor: “movies with Viola Davis”\n- A plot keyword: “heist movies with an all‑female cast”\n\nWhich one should I search for now?"</pre>

# %%
pprint(res['messages'][-1].content)
# Out:
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>"I found several movies titled \"Oppenheimer\". The most prominent one, released in 2023, is a biographical drama about J. Robert Oppenheimer's role in the development of the atomic bomb. Would you like to know more about this specific movie, or perhaps another one?"</pre>
