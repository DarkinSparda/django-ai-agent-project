# %%
import setup
setup.init()

from aiproject.prettifier import pprint
from ai.agents import get_document_agent, get_movies_agent
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()
doc_agent = get_document_agent(checkpointer)
mov_agent = get_movies_agent(checkpointer)

# %%
res = mov_agent.invoke(
    {"messages": [{
        "role": 'user',
        "content": "search about openhaimer",
    }
    ]},
    config=config,
    stream_mode=None,
    checkpointer=checkpointer
    
)
# Out:
#   Cell In[2], line 8
#     stream_mode=Nonenfig=config,
#                         ^
# SyntaxError: invalid syntax

# %%
from ai.supervisors import get_supervisor

supervisor = get_supervisor(checkpointer)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 res = mov_agent.invoke(
#       2     {"messages": [{
#       3         "role": 'user',
#       4         "content": "search about oppenheimer",
#       5     }]},
#       6     config,
#       7     stream_mode=None
#       8 )
#
# File ~/Desktop/personal_projects/django-ai-agent-project/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
# ...

# %%
from tmdb import client as tmdb_client

# %%
tmdb_client.get_headers()
# Out:
# {'accept': 'application/json',
#  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1MTdlODA5NjFiYzBiM2QxNDIzNDcwNTYyOWRlMjhlMyIsIm5iZiI6MTc2MjQzMjMxMS41ODIsInN1YiI6IjY5MGM5NTM3MTFjZTcyOTg2NjA3MTYxZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.KW6z9BVy_1KJwmnHVBKXejrcy8ImntuUTeo-aK1sUco'}

# %%
tmdb_client.movie_details(872585)
# Out:
# {'adult': False,
#  'backdrop_path': '/neeNHeXjMF5fXoCJRsOmkNGC7q.jpg',
#  'belongs_to_collection': None,
#  'budget': 100000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#  'homepage': 'https://www.universalpictures.com/movies/oppenheimer',
#  'id': 872585,
#  'imdb_id': 'tt15398776',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Oppenheimer',
#  'overview': "The story of J. Robert Oppenheimer's role in the development of the atomic bomb during World War II.",
#  'popularity': 18.3298,
#  'poster_path': '/8Gxv8gSFCU0XGDykEGv7zR1n2ua.jpg',
#  'production_companies': [{'id': 9996,
#    'logo_path': '/3tvBqYsBhxWeHlu62SIJ1el93O7.png',
#    'name': 'Syncopy',
#    'origin_country': 'GB'},
#   {'id': 33,
#    'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#    'name': 'Universal Pictures',
#    'origin_country': 'US'},
#   {'id': 507,
#    'logo_path': '/aRmHe6GWxYMRCQljF75rn2B9Gv8.png',
# ...

# %%
import uuid

config = {"configurable": {
    "user_id": '2',
    "thread_id": uuid.uuid4(),
    }
}

# %%
content = "" \
"I want you to search for a movie called (Mad Max 1) and give me a brief summary about it. then create a document for me" \
"called (The Mad Document) and its content should be the brief summary you already did."
res = supervisor.invoke(
    {"messages": [{
        "role": 'user',
        "content": content,
    }
    ]},
    config,
    checkpointer=checkpointer
)
res
pprint(res['messages'][-1].content)
# Out:
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>"I have searched for the movie \"Formula 1 - Speed Fever\", summarized its content, and saved it as \"Formula 1 - Speed Fever Summary\" in your documents. I've also listed your documents, which now include this new summary."</pre>

# %%
for x in res['messages']:
    print(x.content)
# Out:
# Search about the movie Formula 1 and then make a summary about it and save it to my documents with a proper name you choose. then tell me what you did exactly and show me list of my docs.
# I can help you with that! First, I'll search for information about the movie "Formula 1," then I'll summarize it and save it to your documents. Finally, I'll let you know what I've done and show you a list of your documents.
# Successfully transferred to movies-assistant
# I found a movie titled "Formula 1 - Speed fever". It's a documentary from 1978 that features interviews with famous Formula 1 champions like Lauda, Regazzoni, Andretti, Fittipaldi, Villeneuve, and Reutemann. The film also includes footage of races on famous tracks and highlights accidents.
#
# I have saved this information in a document named "Formula 1 - Speed Fever Summary".
#
# I have also listed your documents for you:
# - Formula 1 - Speed Fever Summary
# Transferring back to supervisor
# ...

# %%
res = supervisor.invoke(
    {"messages": [{
        "role": 'user',
        "content": "list my docs",
    }
    ]},
    config,
    checkpointer=checkpointer
)
res
pprint(res['messages'])
# Out:
# Config:  {'tags': [], 'metadata': {'user_id': '2', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'document-assistant:ff9f7c47-5f30-acb1-f6b0-441e622014e4|tools:cd8ce9d6-3404-caab-455f-58e73c60726b', 'checkpoint_ns': 'document-assistant:ff9f7c47-5f30-acb1-f6b0-441e622014e4'}, 'callbacks': <langchain_core.callbacks.manager.CallbackManager object at 0x7d561c1fc3b0>, 'recursion_limit': 25, 'configurable': {'user_id': '2', 'thread_id': UUID('dde4d39e-20ea-4074-b9ea-0a7299a7f204'), '__pregel_runtime': Runtime(context=None, store=None, stream_writer=<function Pregel.stream.<locals>.stream_writer at 0x7d561c39a5c0>, previous=None), '__pregel_task_id': 'cd8ce9d6-3404-caab-455f-58e73c60726b', '__pregel_send': <built-in method extend of collections.deque object at 0x7d561c32aa70>, '__pregel_read': functools.partial(<function local_read at 0x7d56268dfd80>, PregelScratchpad(step=2
# ...

# %%
pprint(res['messages'])
# Out:
# <pre style='font-size:13px;line-height:1.4;font-family:Courier,monospace;overflow-x:auto;margin:0;'>[
#   {
#     <span style="color:#0066cc;">"content":</span> "list my docs",
#     <span style="color:#0066cc;">"additional_kwargs":</span> {},
#     <span style="color:#0066cc;">"response_metadata":</span> {},
#     <span style="color:#0066cc;">"type":</span> "human",
#     <span style="color:#0066cc;">"name":</span> <span style="color:#FF8C00;">null</span>,
#     <span style="color:#0066cc;">"id":</span> "ff04b34f-ef02-4543-a526-28d6570f8335"
#   },
#   {
#     <span style="color:#0066cc;">"content":</span> "",
#     <span style="color:#0066cc;">"additional_kwargs":</span> {
#       <span style="color:#0066cc;">"function_call":</span> {
#         <span style="color:#0066cc;">"name":</span> "transfer_to_document-assistant",
#         <span style="color:#0066cc;">"arguments":</span> "{}"
#       }
#     },
#     <span style="color:#0066cc;">"response_metadata":</span> {
# ...
