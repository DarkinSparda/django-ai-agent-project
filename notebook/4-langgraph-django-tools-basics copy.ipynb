# %%
import setup
setup.init()
# Out:
# ABC

# %%
from ai.tools import get_document, list_documents

# %%
config = {
    "user_id": 4
}

# %%
list_documents.invoke(None, config)
# Out:
# Config:  {'tags': [], 'metadata': {'user_id': 4}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 4}}
# [{'id': 5, 'title': "id4's private DOC"}]

# %%
get_document.invoke({"doc_id": 5}, config)
# Out:
# Config:  {'tags': [], 'metadata': {'user_id': 4}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 4}}
# {'id': 5, 'title': "id4's private DOC"}

# %%
pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (0.3.35)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-openai) (0.3.78)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-openai) (2.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: requests>=2.26.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.104.2->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/abdullah-mohammed/Desktop/personal_projects/django-ai-agent-project/venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
